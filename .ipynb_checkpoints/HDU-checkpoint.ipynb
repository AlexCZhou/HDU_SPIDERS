# %%
import re
import csv
import time
import json
import pymysql
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from requests.exceptions import RequestException

def parse_Problem_Archive(text):
    soup = BeautifulSoup(text, 'lxml')
    items = soup.find_all(align='center', height='22')
    for i in range(1, len(items)):
        Pro_ID = items[i].td.text #items[i]中第一个td的文本内容
        tags = set(parse_discuss_page(Pro_ID)) #利用set去重
        tags = ','.join(tags)
        if len(tags) == 0:
            continue
        data = {
            'Pro_ID': Pro_ID,
            'Title': items[i].a.text.strip(),
            'Tags': tags, 
            'Ratio': items[i].td.next_sibling.next_sibling.text[:6],
            'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=' + Pro_ID
        }
        yield data
        
def get_one_page(url):
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_3) '
            + 'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.162 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.text
        return 'status_code = ' + str(response.status_code)
    except RequestException:
        return 'RequestException'

def parse_discuss_page(Pro_ID):
    url = 'http://acm.hdu.edu.cn/discuss/problem/list.php?problemid=' + str(Pro_ID)
    text = get_one_page(url)
    soup = BeautifulSoup(text, 'lxml')
    discuss_list = soup.select('#ulframe > li > a:nth-child(2)')
    discuss_text = ''
    for d in discuss_list:
        discuss_text += d.text
    match = {
        'dp': re.compile('dp', re.I), #re.I使匹配对大小写不敏感
        'water': re.compile('水'),
        'search': re.compile('[d|b]fs', re.I), #[]
        'sort': re.compile('排序'),
        'tree': re.compile('树'),
        'violence': re.compile('暴力')
    }
    tags = []
    for m in match:
        tags += re.findall(match[m], discuss_text)
    return tags

def write_to_file(item):
    with open('HDU题目类型.txt', 'a', encoding='utf-8') as f:
        f.write(json.dumps(item, ensure_ascii=False)+'\n')
def write_to_json(content):
    with open('HDU题目类型.json', 'a', encoding='utf-8') as f:
        f.write(json.dumps(content, ensure_ascii=False)+'\n')
def write_to_csv(content): 
    with open('HDU题目类型.csv', 'a', encoding='utf-8-sig', newline='') as f:
        #newline=''取消自动换行
        #注意：utf-8还是乱码，得设置为utf-8-sig
        fieldnames = ['Pro_ID', 'Title', 'Tags', 'Ratio', 'Link']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(content)
        
def create_sql():
    db = pymysql.connect(host='localhost',user='root',password='123456',port=3306)
    cursor = db.cursor()
    cursor.execute("CREATE DATABASE spiders DEFAULT CHARACTER SET utf8") #创建数据库spiders
    
    db = pymysql.connect(host='localhost', user='root', password='123456', port=3306, db='spiders')
    cursor = db.cursor() 
    sql= "CREATE TABLE HDU (Pro_ID VARCHAR(255) NOT NULL,Title VARCHAR(255) NOT NULL,Tags VARCHAR(255) NOT NULL,Ratio VARCHAR(255) NOT NULL,Link VARCHAR(255) NOT NULL)"
    cursor.execute(sql) #执行SQL语句，创建数据表HDU
    db.close()
    
def write_to_sql(data):
    table = 'HDU' #表名
    keys = ', '.join(data.keys())
    values = ', '.join(['%s'] * len(data))
    sql = 'INSERT INTO {table}({keys}) VALUES ({values}) ON DUPLICATE KEY UPDATE '.format(table=table, keys=keys, values=values)
    update = ','.join(["{key} = %s".format(key=key) for key in data])
    sql += update 
    db = pymysql.connect(host='localhost', user='root', password='123456', port=3306, db='spiders')
    cursor = db.cursor()
    try:
        if cursor.execute(sql, tuple(data.values())*2):
            print('Successful')
            db.commit()
    except:
        print('Failed')
        db.rollback()
    db.close() 
    
def main():
    #Problem Archive页面经动态渲染，requests无法爬取，
    #于是利用selenum模拟浏览器操作，实现所见即所得
    browser = webdriver.Chrome()
    #create_sql() #第一次创建时使用
    for i in range(1,2):
        url = 'http://acm.hdu.edu.cn/listproblem.php?vol=' + str(i)
        browser.get(url)
        content = []
        text = browser.page_source
        print('正在爬取第', i, '页')
        for item in parse_Problem_Archive(text):
            print(item)
            write_to_file(item)
            write_to_sql(item)
            content.append(item)
        write_to_json(content)
        write_to_csv(content)
        time.sleep(3)
    browser.close()
        
main()
# Out:
# 正在爬取第 1 页
# {'Pro_ID': '1000', 'Title': 'A + B Problem', 'Tags': '水', 'Ratio': '29.85%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1000'}
# Successful
# {'Pro_ID': '1005', 'Title': 'Number Sequence', 'Tags': '水', 'Ratio': '25.38%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1005'}
# Successful
# {'Pro_ID': '1006', 'Title': 'Tick and Tick', 'Tags': '暴力', 'Ratio': '27.28%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1006'}
# Successful
# {'Pro_ID': '1007', 'Title': 'Quoit Design', 'Tags': '树,水', 'Ratio': '26.66%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1007'}
# Successful
# {'Pro_ID': '1008', 'Title': 'Elevator', 'Tags': '水', 'Ratio': '54.23%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1008'}
# Successful
# {'Pro_ID': '1009', 'Title': "FatMouse' Trade", 'Tags': '水', 'Ratio': '34.48%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1009'}
# Successful
# {'Pro_ID': '1010', 'Title': 'Tempter of the Bone', 'Tags': 'DFS,BFS', 'Ratio': '26.55%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1010'}
# Successful
# {'Pro_ID': '1012', 'Title': 'u Calculate e', 'Tags': '水', 'Ratio': '45.75%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1012'}
# Successful
# {'Pro_ID': '1013', 'Title': 'Digital Roots', 'Tags': '水', 'Ratio': '30.98%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1013'}
# Successful
# {'Pro_ID': '1014', 'Title': 'Uniform Generator', 'Tags': '水', 'Ratio': '39.43%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1014'}
# Successful
# {'Pro_ID': '1015', 'Title': 'Safecracker', 'Tags': 'dfs,水', 'Ratio': '52.05%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1015'}
# Successful
# {'Pro_ID': '1016', 'Title': 'Prime Ring Problem', 'Tags': 'DFS,dfs', 'Ratio': '41.26%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1016'}
# Successful
# {'Pro_ID': '1017', 'Title': 'A Mathematical Curiosity', 'Tags': '水,暴力', 'Ratio': '26.34%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1017'}
# Successful
# {'Pro_ID': '1018', 'Title': 'Big Number', 'Tags': '水', 'Ratio': '48.93%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1018'}
# Successful
# {'Pro_ID': '1019', 'Title': 'Least Common Multiple', 'Tags': '水,暴力', 'Ratio': '38.23%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1019'}
# Successful
# {'Pro_ID': '1020', 'Title': 'Encoding', 'Tags': '水', 'Ratio': '44.84%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1020'}
# Successful
# {'Pro_ID': '1021', 'Title': 'Fibonacci Again', 'Tags': '水', 'Ratio': '44.99%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1021'}
# Successful
# {'Pro_ID': '1023', 'Title': 'Train Problem II', 'Tags': '水', 'Ratio': '53.23%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1023'}
# Successful
# {'Pro_ID': '1024', 'Title': 'Max Sum Plus Plus', 'Tags': '水,dp', 'Ratio': '36.36%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1024'}
# Successful
# {'Pro_ID': '1026', 'Title': 'Ignatius and the Princess I', 'Tags': 'BFS,dfs,bfs', 'Ratio': '32.25%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1026'}
# Successful
# {'Pro_ID': '1027', 'Title': 'Ignatius and the Princess II', 'Tags': 'dfs,水', 'Ratio': '57.32%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1027'}
# Successful
# {'Pro_ID': '1028', 'Title': 'Ignatius and the Princess III', 'Tags': 'dp,暴力', 'Ratio': '68.31%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1028'}
# Successful
# {'Pro_ID': '1029', 'Title': 'Ignatius and the Princess IV', 'Tags': '水', 'Ratio': '45.09%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1029'}
# Successful
# {'Pro_ID': '1031', 'Title': 'Design T-Shirt', 'Tags': '水,排序', 'Ratio': '48.27%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1031'}
# Successful
# {'Pro_ID': '1032', 'Title': 'The 3n + 1 problem', 'Tags': '暴力,排序', 'Ratio': '36.10%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1032'}
# Successful
# {'Pro_ID': '1033', 'Title': 'Edge', 'Tags': '水', 'Ratio': '59.71%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1033'}
# Successful
# {'Pro_ID': '1034', 'Title': 'Candy Sharing Game', 'Tags': '水', 'Ratio': '57.25%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1034'}
# Successful
# {'Pro_ID': '1035', 'Title': 'Robot Motion', 'Tags': 'BFS', 'Ratio': '46.55%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1035'}
# Successful
# {'Pro_ID': '1036', 'Title': 'Average is not Fast Enough!', 'Tags': '水', 'Ratio': '42.23%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1036'}
# Successful
# {'Pro_ID': '1037', 'Title': "Keep on Truckin'", 'Tags': '水', 'Ratio': '66.26%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1037'}
# Successful
# {'Pro_ID': '1039', 'Title': 'Easier Done Than Said?', 'Tags': '水', 'Ratio': '47.40%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1039'}
# Successful
# {'Pro_ID': '1040', 'Title': 'As Easy As A+B', 'Tags': '水,排序', 'Ratio': '42.04%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1040'}
# Successful
# {'Pro_ID': '1041', 'Title': 'Computer Transformation', 'Tags': 'DP,水', 'Ratio': '37.61%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1041'}
# Successful
# {'Pro_ID': '1042', 'Title': 'N!', 'Tags': '暴力', 'Ratio': '29.88%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1042'}
# Successful
# {'Pro_ID': '1043', 'Title': 'Eight', 'Tags': 'BFS,暴力', 'Ratio': '25.61%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1043'}
# Successful
# {'Pro_ID': '1044', 'Title': 'Collect More Jewels', 'Tags': 'BFS,DFS', 'Ratio': '23.69%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1044'}
# Successful
# {'Pro_ID': '1045', 'Title': 'Fire Net', 'Tags': 'dfs,水,暴力', 'Ratio': '60.94%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1045'}
# Successful
# {'Pro_ID': '1046', 'Title': 'Gridland', 'Tags': '水', 'Ratio': '45.89%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1046'}
# Successful
# {'Pro_ID': '1047', 'Title': 'Integer Inquiry', 'Tags': '水', 'Ratio': '28.54%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1047'}
# Successful
# {'Pro_ID': '1049', 'Title': 'Climbing Worm', 'Tags': '水', 'Ratio': '67.90%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1049'}
# Successful
# {'Pro_ID': '1050', 'Title': 'Moving Tables', 'Tags': '排序', 'Ratio': '32.45%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1050'}
# Successful
# {'Pro_ID': '1051', 'Title': 'Wooden Sticks', 'Tags': '排序', 'Ratio': '40.51%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1051'}
# Successful
# {'Pro_ID': '1053', 'Title': 'Entropy', 'Tags': '树,水', 'Ratio': '42.64%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1053'}
# Successful
# {'Pro_ID': '1054', 'Title': 'Strategic Game', 'Tags': 'DP,树,dp', 'Ratio': '47.14%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1054'}
# Successful
# {'Pro_ID': '1055', 'Title': 'Color a Tree', 'Tags': 'dfs', 'Ratio': '36.73%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1055'}
# Successful
# {'Pro_ID': '1057', 'Title': 'A New Growth Industry', 'Tags': '水', 'Ratio': '38.57%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1057'}
# Successful
# {'Pro_ID': '1058', 'Title': 'Humble Numbers', 'Tags': 'DP,暴力', 'Ratio': '43.63%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1058'}
# Successful
# {'Pro_ID': '1059', 'Title': 'Dividing', 'Tags': '水', 'Ratio': '28.05%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1059'}
# Successful
# {'Pro_ID': '1061', 'Title': 'Rightmost Digit', 'Tags': '水', 'Ratio': '36.80%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1061'}
# Successful
# {'Pro_ID': '1063', 'Title': 'Exponentiation', 'Tags': '暴力', 'Ratio': '30.25%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1063'}
# Successful
# {'Pro_ID': '1064', 'Title': 'Financial Management', 'Tags': '水', 'Ratio': '56.44%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1064'}
# Successful
# {'Pro_ID': '1069', 'Title': 'Monkey and Banana', 'Tags': 'DP,dp', 'Ratio': '53.70%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1069'}
# Successful
# {'Pro_ID': '1070', 'Title': 'Milk', 'Tags': '水', 'Ratio': '27.78%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1070'}
# Successful
# {'Pro_ID': '1071', 'Title': 'The area', 'Tags': '水', 'Ratio': '69.82%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1071'}
# Successful
# {'Pro_ID': '1072', 'Title': 'Nightmare', 'Tags': 'BFS,dfs', 'Ratio': '48.71%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1072'}
# Successful
# {'Pro_ID': '1073', 'Title': 'Online Judge', 'Tags': '水', 'Ratio': '36.63%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1073'}
# Successful
# {'Pro_ID': '1074', 'Title': 'Doing Homework', 'Tags': 'DP', 'Ratio': '48.45%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1074'}
# Successful
# {'Pro_ID': '1076', 'Title': 'An Easy Task', 'Tags': '水,暴力', 'Ratio': '64.35%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1076'}
# Successful
# {'Pro_ID': '1080', 'Title': 'Human Gene Functions', 'Tags': 'DP', 'Ratio': '54.92%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1080'}
# Successful
# {'Pro_ID': '1081', 'Title': 'To The Max', 'Tags': 'DP,水,dp,暴力', 'Ratio': '45.52%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1081'}
# Successful
# {'Pro_ID': '1082', 'Title': 'Matrix Chain Multiplication', 'Tags': '水', 'Ratio': '61.20%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1082'}
# Successful
# {'Pro_ID': '1084', 'Title': 'What Is Your Grade?', 'Tags': '水', 'Ratio': '31.91%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1084'}
# Successful
# {'Pro_ID': '1086', 'Title': 'You can Solve a Geometry Problem too', 'Tags': '水', 'Ratio': '49.07%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1086'}
# Successful
# {'Pro_ID': '1087', 'Title': 'Super Jumping! Jumping! Jumping!', 'Tags': 'DP,水,dp', 'Ratio': '46.51%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1087'}
# Successful
# {'Pro_ID': '1089', 'Title': 'A+B for Input-Output Practice (I)', 'Tags': '水', 'Ratio': '51.38%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1089'}
# Successful
# {'Pro_ID': '1090', 'Title': 'A+B for Input-Output Practice (II)', 'Tags': '水', 'Ratio': '62.83%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1090'}
# Successful
# {'Pro_ID': '1093', 'Title': 'A+B for Input-Output Practice (V)', 'Tags': '水', 'Ratio': '65.81%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1093'}
# Successful
# {'Pro_ID': '1094', 'Title': 'A+B for Input-Output Practice (VI)', 'Tags': '水', 'Ratio': '65.51%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1094'}
# Successful
# {'Pro_ID': '1095', 'Title': 'A+B for Input-Output Practice (VII)', 'Tags': '水', 'Ratio': '65.50%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1095'}
# Successful
# {'Pro_ID': '1098', 'Title': "Ignatius's puzzle", 'Tags': '水', 'Ratio': '69.95%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1098'}
# Successful
# {'Pro_ID': '1099', 'Title': 'Lottery', 'Tags': '水', 'Ratio': '44.72%', 'Link': 'http://acm.hdu.edu.cn/showproblem.php?pid=1099'}
# Successful
